# %%
# %pip install evidently great-expectations
# Out:
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting evidently
#   Downloading evidently-0.4.33-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 12.2 MB/s eta 0:00:00
# Collecting great-expectations
#   Downloading great_expectations-0.18.19-py3-none-any.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 29.1 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-http>=1.25.0
#   Downloading opentelemetry_exporter_otlp_proto_http-1.26.0-py3-none-any.whl (16 kB)
# Collecting plotly>=5.10.0
#   Downloading plotly-5.23.0-py3-none-any.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 42.8 MB/s eta 0:00:00
# Collecting requests>=2.32.0
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 9.5 MB/s eta 0:00:00
# Collecting litestar>=2.8.3
#   Downloading litestar-2.10.0-py3-none-any.whl (531 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.5/531.5 kB 39.4 MB/s eta 0:00:00
# Collecting watchdog>=3.0.0
#   Downloading watchdog-4.0.1-py3-none-manylinux2014_x86_64.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 12.7 MB/s eta 0:00:00
# Collecting pydantic>=1.10.13
#   Downloading pydantic-2.8.2-py3-none-any.whl (423 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.9/423.9 kB 16.4 MB/s eta 0:00:00
# Collecting fsspec>=2024.2.0
#   Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.0 in /databricks/python3/lib/python3.10/site-packages (from evidently) (1.23.5)
# Collecting certifi>=2024.7.4
#   Downloading certifi-2024.7.4-py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.0/163.0 kB 13.5 MB/s eta 0:00:00
# Collecting urllib3>=1.26.19
#   Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: ujson>=5.4.0 in /databricks/python3/lib/python3.10/site-packages (from evidently) (5.4.0)
# Requirement already satisfied: statsmodels>=0.12.2 in /databricks/python3/lib/python3.10/site-packages (from evidently) (0.13.5)
# Requirement already satisfied: nltk>=3.6.7 in /databricks/python3/lib/python3.10/site-packages (from evidently) (3.7)
# Requirement already satisfied: scipy>=1.10.0 in /databricks/python3/lib/python3.10/site-packages (from evidently) (1.10.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.25.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.26.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: typing-inspect>=0.9.0 in /databricks/python3/lib/python3.10/site-packages (from evidently) (0.9.0)
# Collecting uvicorn[standard]>=0.22.0
#   Downloading uvicorn-0.30.5-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 7.7 MB/s eta 0:00:00
# Collecting opentelemetry-sdk>=1.25.0
#   Downloading opentelemetry_sdk-1.26.0-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=1.0.1 in /databricks/python3/lib/python3.10/site-packages (from evidently) (1.1.1)
# Collecting rich>=13
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas[parquet]>=1.3.5 in /databricks/python3/lib/python3.10/site-packages (from evidently) (1.5.3)
# Requirement already satisfied: PyYAML>=5.4 in /databricks/python3/lib/python3.10/site-packages (from evidently) (6.0)
# Requirement already satisfied: typer>=0.3 in /databricks/python3/lib/python3.10/site-packages (from evidently) (0.9.0)
# Collecting dynaconf>=3.2.4
#   Downloading dynaconf-3.2.6-py2.py3-none-any.whl (231 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.1/231.1 kB 27.9 MB/s eta 0:00:00
# Collecting iterative-telemetry>=0.0.5
#   Downloading iterative_telemetry-0.0.8-py3-none-any.whl (10 kB)
# Collecting opentelemetry-proto>=1.25.0
#   Downloading opentelemetry_proto-1.26.0-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 6.0 MB/s eta 0:00:00
# Collecting opentelemetry-api>=1.25.0
#   Downloading opentelemetry_api-1.26.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.10/site-packages (from great-expectations) (2.8.2)
# Requirement already satisfied: pyparsing>=2.4 in /databricks/python3/lib/python3.10/site-packages (from great-expectations) (3.0.9)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.10/site-packages (from great-expectations) (23.2)
# Requirement already satisfied: notebook>=6.4.10 in /databricks/python3/lib/python3.10/site-packages (from great-expectations) (6.5.2)
# Requirement already satisfied: mistune>=0.8.4 in /databricks/python3/lib/python3.10/site-packages (from great-expectations) (0.8.4)
# Collecting colorama>=0.4.3
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting tzlocal>=1.2
#   Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Collecting altair<5.0.0,>=4.2.1
#   Downloading altair-4.2.2-py3-none-any.whl (813 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.6/813.6 kB 46.1 MB/s eta 0:00:00
# Collecting ruamel.yaml<0.18,>=0.16
#   Downloading ruamel.yaml-0.17.40-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.7/113.7 kB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.59.0 in /databricks/python3/lib/python3.10/site-packages (from great-expectations) (4.64.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.7.1 in /databricks/python3/lib/python3.10/site-packages (from great-expectations) (3.20.2)
# Requirement already satisfied: Click>=7.1.2 in /databricks/python3/lib/python3.10/site-packages (from great-expectations) (8.0.4)
# Collecting makefun<2,>=1.7.0
#   Downloading makefun-1.15.4-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: Ipython>=7.16.3 in /databricks/python3/lib/python3.10/site-packages (from great-expectations) (8.14.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /databricks/python3/lib/python3.10/site-packages (from great-expectations) (4.4.0)
# Requirement already satisfied: pytz>=2021.3 in /databricks/python3/lib/python3.10/site-packages (from great-expectations) (2022.7)
# Requirement already satisfied: jsonschema>=2.5.1 in /databricks/python3/lib/python3.10/site-packages (from great-expectations) (4.17.3)
# Requirement already satisfied: jinja2>=2.10 in /databricks/python3/lib/python3.10/site-packages (from great-expectations) (3.1.2)
# Requirement already satisfied: jsonpatch>=1.22 in /databricks/python3/lib/python3.10/site-packages (from great-expectations) (1.33)
# Requirement already satisfied: cryptography>=3.2 in /databricks/python3/lib/python3.10/site-packages (from great-expectations) (39.0.1)
# Requirement already satisfied: ipywidgets>=7.5.1 in /databricks/python3/lib/python3.10/site-packages (from great-expectations) (7.7.2)
# Requirement already satisfied: nbformat>=5.0 in /databricks/python3/lib/python3.10/site-packages (from great-expectations) (5.7.0)
# Requirement already satisfied: entrypoints in /databricks/python3/lib/python3.10/site-packages (from altair<5.0.0,>=4.2.1->great-expectations) (0.4)
# Collecting toolz
#   Downloading toolz-0.12.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.12 in /databricks/python3/lib/python3.10/site-packages (from cryptography>=3.2->great-expectations) (1.15.1)
# Requirement already satisfied: stack-data in /databricks/python3/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /databricks/python3/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations) (3.0.36)
# Requirement already satisfied: backcall in /databricks/python3/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations) (0.2.0)
# Requirement already satisfied: pickleshare in /databricks/python3/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /databricks/python3/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /databricks/python3/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /databricks/python3/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations) (0.1.6)
# Requirement already satisfied: pygments>=2.4.0 in /databricks/python3/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations) (2.11.2)
# Requirement already satisfied: decorator in /databricks/python3/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations) (5.1.1)
# Requirement already satisfied: traitlets>=5 in /databricks/python3/lib/python3.10/site-packages (from Ipython>=7.16.3->great-expectations) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /databricks/python3/lib/python3.10/site-packages (from ipywidgets>=7.5.1->great-expectations) (3.6.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /databricks/python3/lib/python3.10/site-packages (from ipywidgets>=7.5.1->great-expectations) (6.25.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /databricks/python3/lib/python3.10/site-packages (from ipywidgets>=7.5.1->great-expectations) (1.0.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /databricks/python3/lib/python3.10/site-packages (from ipywidgets>=7.5.1->great-expectations) (0.2.0)
# Requirement already satisfied: distro in /usr/lib/python3/dist-packages (from iterative-telemetry>=0.0.5->evidently) (1.7.0)
# Requirement already satisfied: filelock in /databricks/python3/lib/python3.10/site-packages (from iterative-telemetry>=0.0.5->evidently) (3.9.0)
# Requirement already satisfied: appdirs in /databricks/python3/lib/python3.10/site-packages (from iterative-telemetry>=0.0.5->evidently) (1.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.10/site-packages (from jinja2>=2.10->great-expectations) (2.1.1)
# Requirement already satisfied: jsonpointer>=1.9 in /databricks/python3/lib/python3.10/site-packages (from jsonpatch>=1.22->great-expectations) (2.4)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /databricks/python3/lib/python3.10/site-packages (from jsonschema>=2.5.1->great-expectations) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /databricks/python3/lib/python3.10/site-packages (from jsonschema>=2.5.1->great-expectations) (22.1.0)
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Collecting polyfactory>=2.6.3
#   Downloading polyfactory-2.16.2-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.3 MB/s eta 0:00:00
# Collecting msgspec>=0.18.2
#   Downloading msgspec-0.18.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.3/210.3 kB 18.5 MB/s eta 0:00:00
# Requirement already satisfied: multidict>=6.0.2 in /databricks/python3/lib/python3.10/site-packages (from litestar>=2.8.3->evidently) (6.0.4)
# Requirement already satisfied: anyio>=3 in /databricks/python3/lib/python3.10/site-packages (from litestar>=2.8.3->evidently) (3.5.0)
# Collecting httpx>=0.22
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.3 MB/s eta 0:00:00
# Collecting rich-click
#   Downloading rich_click-1.8.3-py3-none-any.whl (35 kB)
# Requirement already satisfied: jupyter-core in /databricks/python3/lib/python3.10/site-packages (from nbformat>=5.0->great-expectations) (5.2.0)
# Requirement already satisfied: fastjsonschema in /databricks/python3/lib/python3.10/site-packages (from nbformat>=5.0->great-expectations) (2.19.1)
# Requirement already satisfied: joblib in /databricks/python3/lib/python3.10/site-packages (from nltk>=3.6.7->evidently) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /databricks/python3/lib/python3.10/site-packages (from nltk>=3.6.7->evidently) (2022.7.9)
# Requirement already satisfied: jupyter-client>=5.3.4 in /databricks/python3/lib/python3.10/site-packages (from notebook>=6.4.10->great-expectations) (7.3.4)
# Requirement already satisfied: nbclassic>=0.4.7 in /databricks/python3/lib/python3.10/site-packages (from notebook>=6.4.10->great-expectations) (0.5.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in /databricks/python3/lib/python3.10/site-packages (from notebook>=6.4.10->great-expectations) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /databricks/python3/lib/python3.10/site-packages (from notebook>=6.4.10->great-expectations) (0.17.1)
# Requirement already satisfied: prometheus-client in /databricks/python3/lib/python3.10/site-packages (from notebook>=6.4.10->great-expectations) (0.14.1)
# Requirement already satisfied: nbconvert>=5 in /databricks/python3/lib/python3.10/site-packages (from notebook>=6.4.10->great-expectations) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /databricks/python3/lib/python3.10/site-packages (from notebook>=6.4.10->great-expectations) (1.5.6)
# Requirement already satisfied: tornado>=6.1 in /databricks/python3/lib/python3.10/site-packages (from notebook>=6.4.10->great-expectations) (6.1)
# Requirement already satisfied: argon2-cffi in /databricks/python3/lib/python3.10/site-packages (from notebook>=6.4.10->great-expectations) (21.3.0)
# Requirement already satisfied: pyzmq>=17 in /databricks/python3/lib/python3.10/site-packages (from notebook>=6.4.10->great-expectations) (23.2.0)
# Collecting deprecated>=1.2.6
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting importlib-metadata<=8.0.0,>=6.0
#   Downloading importlib_metadata-8.0.0-py3-none-any.whl (24 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.26.0
#   Downloading opentelemetry_exporter_otlp_proto_common-1.26.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in /databricks/python3/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.25.0->evidently) (1.48.2)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /databricks/python3/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.25.0->evidently) (1.62.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in /databricks/python3/lib/python3.10/site-packages (from opentelemetry-proto>=1.25.0->evidently) (4.24.0)
# Collecting opentelemetry-semantic-conventions==0.47b0
#   Downloading opentelemetry_semantic_conventions-0.47b0-py3-none-any.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 14.4 MB/s eta 0:00:00
# WARNING: pandas 1.5.3 does not provide the extra 'parquet'
# Requirement already satisfied: tenacity>=6.2.0 in /databricks/python3/lib/python3.10/site-packages (from plotly>=5.10.0->evidently) (8.1.0)
# Collecting typing-extensions>=3.10.0.0
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Collecting pydantic-core==2.20.1
#   Downloading pydantic_core-2.20.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 33.0 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->great-expectations) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.32.0->evidently) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.32.0->evidently) (2.0.4)
# Collecting pygments>=2.4.0
#   Downloading pygments-2.18.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 56.2 MB/s eta 0:00:00
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 9.8 MB/s eta 0:00:00
# Collecting ruamel.yaml.clib>=0.2.7
#   Downloading ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 42.5 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.10/site-packages (from scikit-learn>=1.0.1->evidently) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /databricks/python3/lib/python3.10/site-packages (from statsmodels>=0.12.2->evidently) (0.5.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /databricks/python3/lib/python3.10/site-packages (from typing-inspect>=0.9.0->evidently) (0.4.3)
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.7 MB/s eta 0:00:00
# Collecting httptools>=0.5.0
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 33.7 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 63.6 MB/s eta 0:00:00
# Collecting websockets>=10.4
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 14.9 MB/s eta 0:00:00
# Collecting watchfiles>=0.13
#   Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 51.6 MB/s eta 0:00:00
# Requirement already satisfied: sniffio>=1.1 in /databricks/python3/lib/python3.10/site-packages (from anyio>=3->litestar>=2.8.3->evidently) (1.2.0)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.2->great-expectations) (2.21)
# Requirement already satisfied: wrapt<2,>=1.10 in /databricks/python3/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.25.0->evidently) (1.14.1)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /databricks/python3/lib/python3.10/site-packages (from importlib-metadata<=8.0.0,>=6.0->opentelemetry-api>=1.25.0->evidently) (3.11.0)
# Requirement already satisfied: psutil in /databricks/python3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great-expectations) (5.9.0)
# Requirement already satisfied: debugpy>=1.6.5 in /databricks/python3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great-expectations) (1.6.7)
# Requirement already satisfied: comm>=0.1.1 in /databricks/python3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great-expectations) (0.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /databricks/python3/lib/python3.10/site-packages (from jedi>=0.16->Ipython>=7.16.3->great-expectations) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /databricks/python3/lib/python3.10/site-packages (from jupyter-core->nbformat>=5.0->great-expectations) (2.5.2)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: jupyter-server>=1.8 in /databricks/python3/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=6.4.10->great-expectations) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in /databricks/python3/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=6.4.10->great-expectations) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in /databricks/python3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great-expectations) (0.5.13)
# Requirement already satisfied: defusedxml in /databricks/python3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great-expectations) (0.7.1)
# Requirement already satisfied: bleach in /databricks/python3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great-expectations) (4.1.0)
# Requirement already satisfied: tinycss2 in /databricks/python3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great-expectations) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in /databricks/python3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great-expectations) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /databricks/python3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great-expectations) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in /databricks/python3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great-expectations) (0.1.2)
# Requirement already satisfied: lxml in /databricks/python3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great-expectations) (4.9.1)
# Requirement already satisfied: ptyprocess>=0.5 in /databricks/python3/lib/python3.10/site-packages (from pexpect>4.3->Ipython>=7.16.3->great-expectations) (0.7.0)
# Collecting faker
#   Downloading Faker-26.1.0-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 52.6 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth in /databricks/python3/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->Ipython>=7.16.3->great-expectations) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in /databricks/python3/lib/python3.10/site-packages (from argon2-cffi->notebook>=6.4.10->great-expectations) (21.2.0)
# Requirement already satisfied: pure-eval in /databricks/python3/lib/python3.10/site-packages (from stack-data->Ipython>=7.16.3->great-expectations) (0.2.2)
# Requirement already satisfied: asttokens in /databricks/python3/lib/python3.10/site-packages (from stack-data->Ipython>=7.16.3->great-expectations) (2.0.5)
# Requirement already satisfied: executing in /databricks/python3/lib/python3.10/site-packages (from stack-data->Ipython>=7.16.3->great-expectations) (0.8.3)
# Requirement already satisfied: websocket-client in /databricks/python3/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great-expectations) (0.58.0)
# Requirement already satisfied: soupsieve>1.2 in /databricks/python3/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=6.4.10->great-expectations) (2.3.2.post1)
# Requirement already satisfied: webencodings in /databricks/python3/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=6.4.10->great-expectations) (0.5.1)
# Installing collected packages: makefun, websockets, watchdog, uvloop, urllib3, tzlocal, typing-extensions, toolz, ruamel.yaml.clib, python-dotenv, pygments, plotly, opentelemetry-proto, msgspec, mdurl, importlib-metadata, httptools, h11, fsspec, exceptiongroup, dynaconf, deprecated, colorama, certifi, annotated-types, watchfiles, uvicorn, ruamel.yaml, requests, pydantic-core, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, markdown-it-py, httpcore, faker, rich, pydantic, polyfactory, opentelemetry-semantic-conventions, iterative-telemetry, httpx, altair, rich-click, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, litestar, evidently, great-expectations
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.14
#     Not uninstalling urllib3 at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-a2aaa94c-80b2-421e-948d-01e65578c070
#     Can't uninstall 'urllib3'. No files were found to uninstall.
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.4.0
#     Not uninstalling typing-extensions at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-a2aaa94c-80b2-421e-948d-01e65578c070
#     Can't uninstall 'typing_extensions'. No files were found to uninstall.
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.11.2
#     Not uninstalling pygments at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-a2aaa94c-80b2-421e-948d-01e65578c070
#     Can't uninstall 'Pygments'. No files were found to uninstall.
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.9.0
#     Not uninstalling plotly at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-a2aaa94c-80b2-421e-948d-01e65578c070
#     Can't uninstall 'plotly'. No files were found to uninstall.
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.3
#     Not uninstalling importlib-metadata at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-a2aaa94c-80b2-421e-948d-01e65578c070
#     Can't uninstall 'importlib-metadata'. No files were found to uninstall.
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.6.0
#     Not uninstalling fsspec at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-a2aaa94c-80b2-421e-948d-01e65578c070
#     Can't uninstall 'fsspec'. No files were found to uninstall.
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2022.12.7
#     Not uninstalling certifi at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-a2aaa94c-80b2-421e-948d-01e65578c070
#     Can't uninstall 'certifi'. No files were found to uninstall.
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Not uninstalling requests at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-a2aaa94c-80b2-421e-948d-01e65578c070
#     Can't uninstall 'requests'. No files were found to uninstall.
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.6
#     Not uninstalling pydantic at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-a2aaa94c-80b2-421e-948d-01e65578c070
#     Can't uninstall 'pydantic'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# petastorm 0.12.1 requires pyspark>=2.1.0, which is not installed.
# databricks-feature-engineering 0.2.1 requires pyspark<4,>=3.1.2, which is not installed.
# ydata-profiling 4.2.0 requires pydantic<2,>=1.8.1, but you have pydantic 2.8.2 which is incompatible.
# mlflow-skinny 2.9.2 requires importlib-metadata!=4.7.0,<8,>=3.7.0, but you have importlib-metadata 8.0.0 which is incompatible.
# google-auth 2.21.0 requires urllib3<2.0, but you have urllib3 2.2.2 which is incompatible.
# datasets 2.15.0 requires fsspec[http]<=2023.10.0,>=2023.1.0, but you have fsspec 2024.6.1 which is incompatible.
# databricks-sdk 0.1.6 requires requests<2.29.0,>=2.28.1, but you have requests 2.32.3 which is incompatible.
# botocore 1.27.96 requires urllib3<1.27,>=1.25.4, but you have urllib3 2.2.2 which is incompatible.
# Successfully installed altair-4.2.2 annotated-types-0.7.0 certifi-2024.7.4 colorama-0.4.6 deprecated-1.2.14 dynaconf-3.2.6 evidently-0.4.33 exceptiongroup-1.2.2 faker-26.1.0 fsspec-2024.6.1 great-expectations-0.18.19 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 importlib-metadata-8.0.0 iterative-telemetry-0.0.8 litestar-2.10.0 makefun-1.15.4 markdown-it-py-3.0.0 mdurl-0.1.2 msgspec-0.18.6 opentelemetry-api-1.26.0 opentelemetry-exporter-otlp-proto-common-1.26.0 opentelemetry-exporter-otlp-proto-grpc-1.26.0 opentelemetry-exporter-otlp-proto-http-1.26.0 opentelemetry-proto-1.26.0 opentelemetry-sdk-1.26.0 opentelemetry-semantic-conventions-0.47b0 plotly-5.23.0 polyfactory-2.16.2 pydantic-2.8.2 pydantic-core-2.20.1 pygments-2.18.0 python-dotenv-1.0.1 requests-2.32.3 rich-13.7.1 rich-click-1.8.3 ruamel.yaml-0.17.40 ruamel.yaml.clib-0.2.8 toolz-0.12.1 typing-extensions-4.12.2 tzlocal-5.2 urllib3-2.2.2 uvicorn-0.30.5 uvloop-0.19.0 watchdog-4.0.1 watchfiles-0.22.0 websockets-12.0
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.

# %%
dbutils.library.restartPython()

# %%
from evidently import ColumnMapping

from evidently.report import Report
from evidently.metrics.base_metric import generate_column_metrics
from evidently.metric_preset import DataDriftPreset, TargetDriftPreset
from evidently.metrics import *

from evidently.test_suite import TestSuite
from evidently.tests.base_test import generate_column_tests
from evidently.test_preset import DataStabilityTestPreset, NoTargetPerformanceTestPreset
from evidently.tests import *

# %%
import great_expectations as gx

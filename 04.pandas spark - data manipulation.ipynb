# %%
import pyspark.pandas as ps

# %%
# https://spark.apache.org/docs/latest/api/python/getting_started/quickstart_ps.html
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", True)

# %% [markdown]
# ### Load dataset

# %%
df_spark = spark.sql('SELECT * FROM samples.nyctaxi.trips')

# %%
df_pandas = df_spark.toPandas()

# %% [markdown]
# ### To pandas-spark and back

# %%
# From pandas to pandas-spark
psdf_from_pandas = ps.from_pandas(df_pandas)

# %%
# From spark to pandas-spark
psdf = df_spark.pandas_api()

# %%
# From pandas-spark to spark
spark_df = psdf.to_spark()
type(spark_df)
# Out:
# pyspark.sql.dataframe.DataFrame

# %% [markdown]
# ### Pandas-spark read/write

# %%
# psdf.to_csv('foo.csv')
# ps.read_csv('foo.csv').head(10)

# psdf.to_parquet('bar.parquet')
# ps.read_parquet('bar.parquet').head(10)
# Out:
# pyspark.sql.dataframe.DataFrame

# %% [markdown]
# ### Pandas-spark introductory

# %%
# df.dtypes
# df.isnull().sum()
# df.pickup_zip.value_counts(ascending=False).head()

# %% [markdown]
# ### Pandas-spark workflow

# %%
# Perform some operations with pandas-on-Spark DataFrame
psdf['fare_per_mile'] = psdf['fare_amount'] / psdf['trip_distance']
psdf['trip_type'] = psdf['trip_distance'].apply(lambda x: 'Long Trip' if x > 10 else 'Short Trip')
psdf['pickup_year'] = ps.to_datetime(psdf['tpep_pickup_datetime']).dt.year

# %%
# Convert pandas-on-Spark DataFrame to Spark DataFrame
spark_df_new = psdf.to_spark()

# %%
# Register the Spark DataFrame as a temporary view
spark_df_new.createOrReplaceTempView("nyctaxi_trips_view")

# %%
# %sql
SELECT * FROM nyctaxi_trips_view LIMIT 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>tpep_pickup_datetime</th><th>tpep_dropoff_datetime</th><th>trip_distance</th><th>fare_amount</th><th>pickup_zip</th><th>dropoff_zip</th><th>fare_per_mile</th><th>trip_type</th><th>pickup_year</th></tr></thead><tbody><tr><td>2016-02-16T22:40:45Z</td><td>2016-02-16T22:59:25Z</td><td>5.35</td><td>18.5</td><td>10003</td><td>11238</td><td>3.457943925233645</td><td>Short Trip</td><td>2016</td></tr><tr><td>2016-02-05T16:06:44Z</td><td>2016-02-05T16:26:03Z</td><td>6.5</td><td>21.5</td><td>10282</td><td>10001</td><td>3.3076923076923075</td><td>Short Trip</td><td>2016</td></tr><tr><td>2016-02-08T07:39:25Z</td><td>2016-02-08T07:44:14Z</td><td>0.9</td><td>5.5</td><td>10119</td><td>10003</td><td>6.111111111111111</td><td>Short Trip</td><td>2016</td></tr><tr><td>2016-02-29T22:25:33Z</td><td>2016-02-29T22:38:09Z</td><td>3.5</td><td>13.5</td><td>10001</td><td>11222</td><td>3.857142857142857</td><td>Short Trip</td><td>2016</td></tr><tr><td>2016-02-03T17:21:02Z</td><td>2016-02-03T17:23:24Z</td><td>0.3</td><td>3.5</td><td>10028</td><td>10028</td><td>11.666666666666668</td><td>Short Trip</td><td>2016</td></tr></tbody></table></div>

# %%
# Register table to hive catalogue
spark_df_new.write.mode("overwrite").saveAsTable("my_database.my_nyctaxi")

# %%
# %sql
SELECT * FROM my_database.my_nyctaxi LIMIT 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>tpep_pickup_datetime</th><th>tpep_dropoff_datetime</th><th>trip_distance</th><th>fare_amount</th><th>pickup_zip</th><th>dropoff_zip</th><th>fare_per_mile</th><th>trip_type</th><th>pickup_year</th></tr></thead><tbody><tr><td>2016-02-16T22:40:45Z</td><td>2016-02-16T22:59:25Z</td><td>5.35</td><td>18.5</td><td>10003</td><td>11238</td><td>3.457943925233645</td><td>Short Trip</td><td>2016</td></tr><tr><td>2016-02-05T16:06:44Z</td><td>2016-02-05T16:26:03Z</td><td>6.5</td><td>21.5</td><td>10282</td><td>10001</td><td>3.3076923076923075</td><td>Short Trip</td><td>2016</td></tr><tr><td>2016-02-08T07:39:25Z</td><td>2016-02-08T07:44:14Z</td><td>0.9</td><td>5.5</td><td>10119</td><td>10003</td><td>6.111111111111111</td><td>Short Trip</td><td>2016</td></tr><tr><td>2016-02-29T22:25:33Z</td><td>2016-02-29T22:38:09Z</td><td>3.5</td><td>13.5</td><td>10001</td><td>11222</td><td>3.857142857142857</td><td>Short Trip</td><td>2016</td></tr><tr><td>2016-02-03T17:21:02Z</td><td>2016-02-03T17:23:24Z</td><td>0.3</td><td>3.5</td><td>10028</td><td>10028</td><td>11.666666666666668</td><td>Short Trip</td><td>2016</td></tr></tbody></table></div>

# %%
# Run SQL queries on the temporary view
result_df = spark.sql("""
    SELECT 
        pickup_zip, 
        dropoff_zip, 
        COUNT(*) AS trip_count, 
        AVG(trip_distance) AS avg_distance, 
        SUM(fare_amount) AS total_fare 
    -- FROM nyctaxi_trips_view 
    FROM my_database.my_nyctaxi
    GROUP BY pickup_zip, dropoff_zip 
    ORDER BY trip_count DESC
""")

# Show the result
display(result_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_zip</th><th>dropoff_zip</th><th>trip_count</th><th>avg_distance</th><th>total_fare</th></tr></thead><tbody><tr><td>10023</td><td>10023</td><td>143</td><td>0.7644755244755245</td><td>798.0</td></tr><tr><td>10028</td><td>10028</td><td>135</td><td>0.6650370370370372</td><td>722.0</td></tr><tr><td>10028</td><td>10021</td><td>131</td><td>0.8712977099236643</td><td>777.5</td></tr><tr><td>10021</td><td>10028</td><td>120</td><td>0.9373333333333332</td><td>684.5</td></tr><tr><td>10021</td><td>10021</td><td>113</td><td>0.651858407079646</td><td>701.5</td></tr><tr><td>10065</td><td>10021</td><td>111</td><td>0.8160360360360359</td><td>608.5</td></tr><tr><td>10003</td><td>10011</td><td>110</td><td>0.9744545454545455</td><td>730.0</td></tr><tr><td>10003</td><td>10009</td><td>107</td><td>0.8752336448598131</td><td>670.0</td></tr><tr><td>10011</td><td>10011</td><td>102</td><td>0.6887254901960784</td><td>537.0</td></tr><tr><td>10023</td><td>10162</td><td>100</td><td>1.0927</td><td>612.5</td></tr><tr><td>10003</td><td>10003</td><td>95</td><td>0.6757894736842104